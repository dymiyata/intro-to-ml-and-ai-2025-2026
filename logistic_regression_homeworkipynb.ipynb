# %% [markdown]
# <a href="https://colab.research.google.com/github/dymiyata/intro-to-ml-and-ai-2025-2026/blob/main/logistic_regression_homeworkipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Logistic Regression Homework:

# %% [markdown]
# As usual, make a copy ,f this notebook and save it to your own google drive.  Then complete the assignment BY WORKING IN THIS NOTEBOOK.
# - Just add extra code cells and text cells to complete the problems and explain your work
# - Don't create your own new notebook from scratch otherwise you may be missing certain imports and things will be much harder to troubleshoot.

# %% [markdown]
# For this homework assignment, you will perform logistic regression on `sklearn`'s wine dataset to classify wines as "good" or "not good".

# %% [markdown]
# First run the following cell to import most of the necessary things.  Do not edit the following cell.

# %%
### DO NOT EDIT THIS CELL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# Next, we load the wine dataset from sklearn.  Do this by running the following cell (do not edit the cell just run it as is).

# %%
### DO NOT EDIT THIS CELL
from sklearn.datasets import load_wine

data = load_wine()
X = pd.DataFrame(data.data, columns=data.feature_names)
y_original = pd.Series(data.target)

# %% [markdown]
# ### Problem 1
#
# Play around with `X` and `y_original` that we defined above to get a feel for what features we have.  Notice that `y_original` doesn't just take on the values $0$ and $1$.  It can be $0$, $1$, or $2$ (think of these as different scores for the wine. $2$ is the worst while $0$ is the best).
#
# Then notice the first two features are the alcohol content (called `"alcohol"`) and the malic acid content (called `"malic_acid"`).
# - Create a scatter plot plotting the alcohol content vs the malic acid content.
# - Add the argument `hue=y_original` to your scatter plot to color the points based on their `y_original` values.
#
# Based on the scatter plot, does it look like these features may help us predict the `y_original` values?

# %% [markdown]
# ### Problem 2
#
# Recall, logistic regression is for *binary classification* meaning we can only predict two different categories (0 and 1).  Thus we will need to edit our `y_original`.  We will do this as follows:
# - A `y_original` score of 0 will mean the wine is "good"
# - A `y_original` score of 1 or 2 will mean the wine is "not good".
#
# Thus, we will need to change the values so that $y=1$ means the wine is "good" and $y=0$ means the wine is "not good".

# %% [markdown]
# To do this by first run the following:

# %%
y_tf = (y_original == 0)
y = y_tf.astype(int)

# %% [markdown]
# Try printing `y_original`, `y_tf`, and `y` to figure out what these two lines of code did.  (the "tf" stands for "true/false").

# %% [markdown]
# Then, explain in your own words what each line did and why this achieved what we wanted (converting the `y_original` scores of $0$ to a `y` score of $1$ and converting the `y_original` scores of 1 or 2 to a `y` score of $0$.

# %% [markdown]
# ### Problem 3
#
# Now split `X` and `y` into a training and testing set.  Make is so that 70% of data is in the training set and 30% of the data is in the testing set.
#
# Be sure to set a random state (so your results are reproducable).  You can pick any number you want.
#
# Don't forget to stratify by `y` so that there is an equal proportion of 1s and 0s in each set.

# %% [markdown]
# ### Problem 4

# %% [markdown]
# Now normalize the features so that they are all roughly the same scale.
#
# Save your scaled feature matrices in `X_train_scaled` and `X_test_scaled` as appropriate.  To check that it worked you can print them and make sure most of the values seem to be centered around 0 and somewhat small (values outside of the interval from -2 to 2 should be quite rare).

# %% [markdown]
# ### Problem 5
#
# Now define and train the logistic regression model on the data set.

# %% [markdown]
# ### Problem 6
#
# Use your trained model to make predictions on both the training set and the test set and display the accuracy of your predictions on each.
#
# (You should have two accuracies.  One for the training set and one for the testing set).

# %% [markdown]
# ### Problem 7
#
# Determine how many false positives and false negatives your model had on the testing set.  (A false positive means your model predicted the wine was good, when actually the wine was not good.  A false negative means your model predicted the wine was good, when actually it was not good)

# %% [markdown]
# Congratulations, you now have a machine learning model that will probably be a better wine critic than most humans would ever be!
