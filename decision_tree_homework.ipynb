# %% [markdown]
# <a href="https://colab.research.google.com/github/dymiyata/intro-to-ml-and-ai-2025-2026/blob/main/decision_tree_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Decision Tree Homework:

# %% [markdown]
# As usual, make a copy of this notebook and save it to your own google drive.  Then complete the assignment BY WORKING IN THIS NOTEBOOK.
# - Just add extra code cells and text cells to complete the problems and explain your work
# - Don't create your own new notebook from scratch otherwise you may be missing certain imports and things will be much harder to troubleshoot.

# %% [markdown]
# For this homework assignment, you will use a decision tree on some used car data to determine whether or not a car is in "acceptable" condition or not.

# %% [markdown]
# First run the following cell to import most of the necessary things.  Do not edit the following cell.

# %%
### DO NOT EDIT THIS CELL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# Next, run the following cell without changing it. This cell loads the dataset. You don't have to worry about what this cell is doing but in case you're curious, it's:
# - downloading a dataset from UC Irvine's Car Evaluation Dataset: [here](https://archive.ics.uci.edu/dataset/19/car+evaluation)
# - creating the target variable which I'm calling "acceptable" from the original datasets "class" variable
#   - if the `"acceptable"` variable is 1, the car is acceptable
#   - if the `"acceptable"` variable is 0, the car is unacceptable
# - defining the feature matrix `X` and target vector `y`

# %%
### DO NOT EDIT THIS CELL
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"

columns = [
    "buying", "maint", "doors",
    "persons", "lug_boot", "safety", "class"
]

df = pd.read_csv(url, names=columns)
df["acceptable"] = df["class"] != "unacc"
df["acceptable"] = df["acceptable"].astype(int)

X = df.drop(columns=["class", "acceptable"])
y = df["acceptable"]

# %% [markdown]
# ### Problem 1
#
# Play around with `X` and `y` to get a feel for the dataset.
#
# Then notice there are some categorical variables. Like we did in class use one-hot-encoding to deal with these variables.
#
# Save the resulting feature matrix in `X_encoded`.

# %% [markdown]
# ### Problem 2
#
# Now split `X` and `y` into a training and testing set.  Make is so that 70% of data is in the training set and 30% of the data is in the testing set.
#
# Be sure to set a random state (so your results are reproducable).  You can pick any number you want.
#
# Don't forget to stratify by `y` so that there is an equal proportion of 1s and 0s in each set.

# %% [markdown]
# ### Problem 3

# %% [markdown]
# Without adjusting any hyperparameters, define and train a `DecisionTreeClassifier` on the training data.

# %% [markdown]
# ### Problem 4
#
# Use your trained model to make predictions for both the training and testing sets. Then print the confusion matrices and evaluation reports for both.
#
# Is there any overfitting?

# %% [markdown]
# ### Problem 5
#
# Tune the max depth hyperparameter. To do this, create a new Decision Tree Classifire and adjust the max depth until you get the best result on the testing set.
